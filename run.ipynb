# %%
import gym
import random

# %% [markdown]
# ## 1.test random environment with openai gym

# %%
env = gym.make('SpaceInvaders-v0')
height,width,channels = env.observation_space.shape
actions = env.action_space.n

# %%
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
episodes = 5
for episode in range(episodes):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = random.choice([0,1,2,3,4,5])
        n_state, reward, done, info = env.step(action)
        score+=reward
        print('Episode:{} Score:{}'.format(episode,score))
        env.close()
# Out:
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:0.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:5.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:15.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:25.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:30.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:45.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:65.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:90.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# Episode:0 Score:120.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-47ad0362b157> in <module>
#       6
#       7     while not done:
# ----> 8         env.render()
#       9         action = random.choice([0,1,2,3,4,5])
#      10         n_state, reward, done, info = env.step(action)
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/gym/envs/atari/atari_env.py in render(self, mode)
#     153             if self.viewer is None:
#     154                 self.viewer = rendering.SimpleImageViewer()
# --> 155             self.viewer.imshow(img)
#     156             return self.viewer.isopen
#     157
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in imshow(self, arr)
#     370         self.window.clear()
#     371         self.window.switch_to()
# --> 372         self.window.dispatch_events()
#     373         texture.blit(0, 0) # draw
#     374         self.window.flip()
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/pyglet/window/cocoa/__init__.py in dispatch_events(self)
#     312                 event_type = event.type()
#     313                 # Pass on all events.
# --> 314                 NSApp.sendEvent_(event)
#     315                 # And resend key events to special handlers.
#     316                 if event_type == cocoapy.NSKeyDown and not event.isARepeat():
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, *args)
#     790     def __call__(self, *args):
#     791         """Call the method with the given arguments."""
# --> 792         return self.method(self.objc_id, *args)
#     793
#     794 ######################################################################
#
# ~/Development/venv/my-venv/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, objc_id, *args)
#     760         f = self.get_callable()
#     761         try:
# --> 762             result = f(objc_id, self.selector, *args)
#     763             # Convert result to python type if it is a instance or class pointer.
#     764             if self.restype == ObjCInstance:
#
# KeyboardInterrupt:

# %% [markdown]
# ## create a deep learning model with keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.layers import Dense,Flatten, Convolution2D
from tensorflow.keras.optimizers import Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-49f18d6fb100> in <module>
#       1 import numpy as np
#       2 from tensorflow.keras.models import Sequential
# ----> 3 from tensorflow.layers import Dense,Flatten, Convolution2D
#       4 from tensorflow.keras.optimizers import Adam
#
# ModuleNotFoundError: No module named 'tensorflow.layers'

# %%
def build_model(height, width, channels, actions):
    model = Sequential()
    model.add(Convolution2D(32,(8,8),strides(4,4),activation='relu',input_shape=(3,height,width,channels)))
    model.add(C)
